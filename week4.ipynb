# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseFERNAN/ML4AI/blob/main/week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02/data/
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02/data

# %%
df = pd.read_csv("earthquakes.csv")

# %%
df.mag[0:3]
# Out:
# 0    1.35
# 1    1.29
# 2    3.42
# Name: mag, dtype: float64

# %%
df[["title", "mag"]][0:10]
# Out:
#                                                title   mag
# 0                      M 1.4 - 9km NE of Aguanga, CA  1.35
# 1                      M 1.3 - 9km NE of Aguanga, CA  1.29
# 2                      M 3.4 - 8km NE of Aguanga, CA  3.42
# 3                      M 0.4 - 9km NE of Aguanga, CA  0.44
# 4                      M 2.2 - 10km NW of Avenal, CA  2.16
# 5  M 2.6 - 55km ESE of Punta Cana, Dominican Repu...  2.61
# 6               M 1.7 - 105km W of Talkeetna, Alaska  1.70
# 7                   M 1.1 - 10km NW of Parkfield, CA  1.13
# 8                  M 0.9 - 6km NW of The Geysers, CA  0.92
# 9            M 4.7 - 219km SSE of Saparua, Indonesia  4.70

# %%
df[df.mag >= 7]
# Out:
#       alert  cdi      code                                             detail  \
# 837   green  4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5263    red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap                                 ids  mag magType  ...  \
# 837   1.763   3.0  14.0  ,us1000haa3,pt18283003,at00pgehsk,  7.0     mww  ...
# 5263  1.589  18.0  27.0             ,us1000h3p4,us1000h4p4,  7.5     mww  ...
#
#          sources    status           time  \
# 837   ,us,pt,at,  reviewed  1539204500290
# 5263     ,us,us,  reviewed  1538128963480
#
#                                            title  tsunami        type  \
# 837   M 7.0 - 117km E of Kimbe, Papua New Guinea        1  earthquake
# 5263           M 7.5 - 78km N of Palu, Indonesia        1  earthquake
#
#                                                   types     tz        updated  \
# ...

# %%
df.loc[
    df.title.str.contains('Philippines'),
    ['title', 'mag']
]
# Out:
#                                              title  mag
# 1471      M 4.5 - 39km ESE of Lamitan, Philippines  4.5
# 1663       M 4.9 - 21km NNE of Cortes, Philippines  4.9
# 2330      M 4.2 - 11km NNW of Itbayat, Philippines  4.2
# 2983        M 4.4 - 5km ESE of Aumbay, Philippines  4.4
# 3069        M 4.5 - 2km NE of Bulusan, Philippines  4.5
# 3581      M 4.7 - 55km S of Sarangani, Philippines  4.7
# 4535      M 4.4 - 135km NNW of Davila, Philippines  4.4
# 4673  M 4.5 - 173km SE of Pondaguitan, Philippines  4.5
# 5428       M 4.3 - 22km ESE of Padong, Philippines  4.3
# 5810   M 5.0 - 45km NNE of San Isidro, Philippines  5.0
# 5811   M 4.7 - 49km N of Santa Monica, Philippines  4.7
# 5933         M 4.4 - 23km ENE of Lais, Philippines  4.4
# 6300    M 4.6 - 56km ENE of Barcelona, Philippines  4.6
# 6756  M 4.5 - 18km NE of General Luna, Philippines  4.5
# 6787   M 4.8 - 38km NNE of San Isidro, Philippines  4.8
# 6941   M 4.5 - 38km NNE of San Isidro, Philippines  4.5
# ...

# %%
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
# ...

# %%
df = pd.read_csv(
    'earthquakes.csv',
    usecols=['title', 'mag', 'place']
    )

# %%
df
# Out:
#        mag                             place  \
# 0     1.35             9km NE of Aguanga, CA
# 1     1.29             9km NE of Aguanga, CA
# 2     3.42             8km NE of Aguanga, CA
# 3     0.44             9km NE of Aguanga, CA
# 4     2.16             10km NW of Avenal, CA
# ...    ...                               ...
# 9327  0.62      9km ENE of Mammoth Lakes, CA
# 9328  1.00               3km W of Julian, CA
# 9329  2.40  35km NNE of Hatillo, Puerto Rico
# 9330  1.10             9km NE of Aguanga, CA
# 9331  0.66             9km NE of Aguanga, CA
#
#                                          title
# 0                M 1.4 - 9km NE of Aguanga, CA
# 1                M 1.3 - 9km NE of Aguanga, CA
# 2                M 3.4 - 8km NE of Aguanga, CA
# 3                M 0.4 - 9km NE of Aguanga, CA
# 4                M 2.2 - 10km NW of Avenal, CA
# ...                                        ...
# 9327      M 0.6 - 9km ENE of Mammoth Lakes, CA
# ...

# %%
df.head()
# Out:
#     mag                  place                          title
# 0  1.35  9km NE of Aguanga, CA  M 1.4 - 9km NE of Aguanga, CA
# 1  1.29  9km NE of Aguanga, CA  M 1.3 - 9km NE of Aguanga, CA
# 2  3.42  8km NE of Aguanga, CA  M 3.4 - 8km NE of Aguanga, CA
# 3  0.44  9km NE of Aguanga, CA  M 0.4 - 9km NE of Aguanga, CA
# 4  2.16  10km NW of Avenal, CA  M 2.2 - 10km NW of Avenal, CA

# %%
df['big_earthquake'] = df.mag > 5

# %%
df.head()
# Out:
#     mag                  place                          title  big_earthquake
# 0  1.35  9km NE of Aguanga, CA  M 1.4 - 9km NE of Aguanga, CA           False
# 1  1.29  9km NE of Aguanga, CA  M 1.3 - 9km NE of Aguanga, CA           False
# 2  3.42  8km NE of Aguanga, CA  M 3.4 - 8km NE of Aguanga, CA           False
# 3  0.44  9km NE of Aguanga, CA  M 0.4 - 9km NE of Aguanga, CA           False
# 4  2.16  10km NW of Avenal, CA  M 2.2 - 10km NW of Avenal, CA           False

# %%
df.loc[df.mag > 5]
# Out:
#       mag                                     place  \
# 118   6.7           262km NW of Ozernovskiy, Russia
# 180   5.2               25km E of Bitung, Indonesia
# 226   5.7                 42km WNW of Sola, Vanuatu
# 227   5.2                   15km WSW of Pisco, Peru
# 258   5.1             236km NNW of Kuril'sk, Russia
# ...   ...                                       ...
# 9175  5.2               126km N of Dili, East Timor
# 9176  5.2       90km S of Raoul Island, New Zealand
# 9211  6.0                    Southwest Indian Ridge
# 9213  5.1                            South of Tonga
# 9304  5.1  34km NW of Finschhafen, Papua New Guinea
#
#                                                  title  big_earthquake
# 118            M 6.7 - 262km NW of Ozernovskiy, Russia            True
# 180                M 5.2 - 25km E of Bitung, Indonesia            True
# 226                  M 5.7 - 42km WNW of Sola, Vanuatu            True
# ...

# %%
ls
# Out:
# earthquakes.csv   parsed.csv  README.md
# example_data.csv  quakes.db   tsunamis.csv

# %%
import matplotlib.pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %%
phi_data = df[1:10]

# %%
phi_data
# Out:
#     mag                                       place  \
# 1  1.29                       9km NE of Aguanga, CA
# 2  3.42                       8km NE of Aguanga, CA
# 3  0.44                       9km NE of Aguanga, CA
# 4  2.16                       10km NW of Avenal, CA
# 5  2.61  55km ESE of Punta Cana, Dominican Republic
# 6  1.70                105km W of Talkeetna, Alaska
# 7  1.13                    10km NW of Parkfield, CA
# 8  0.92                   6km NW of The Geysers, CA
# 9  4.70             219km SSE of Saparua, Indonesia
#
#                                                title  big_earthquake
# 1                      M 1.3 - 9km NE of Aguanga, CA           False
# 2                      M 3.4 - 8km NE of Aguanga, CA           False
# 3                      M 0.4 - 9km NE of Aguanga, CA           False
# 4                      M 2.2 - 10km NW of Avenal, CA           False
# 5  M 2.6 - 55km ESE of Punta Cana, Dominican Repu...           False
# ...

# %%
phi_data = df.loc[df.title.str.contains('Philippines')]

# %%
phi_data
# Out:
#       mag                                 place  \
# 1471  4.5      39km ESE of Lamitan, Philippines
# 1663  4.9       21km NNE of Cortes, Philippines
# 2330  4.2      11km NNW of Itbayat, Philippines
# 2983  4.4        5km ESE of Aumbay, Philippines
# 3069  4.5        2km NE of Bulusan, Philippines
# 3581  4.7      55km S of Sarangani, Philippines
# 4535  4.4      135km NNW of Davila, Philippines
# 4673  4.5  173km SE of Pondaguitan, Philippines
# 5428  4.3       22km ESE of Padong, Philippines
# 5810  5.0   45km NNE of San Isidro, Philippines
# 5811  4.7   49km N of Santa Monica, Philippines
# 5933  4.4         23km ENE of Lais, Philippines
# 6300  4.6    56km ENE of Barcelona, Philippines
# 6756  4.5  18km NE of General Luna, Philippines
# 6787  4.8   38km NNE of San Isidro, Philippines
# 6941  4.5   38km NNE of San Isidro, Philippines
# 7213  4.4      22km ENE of Itbayat, Philippines
# 8624  5.1  278km SE of Pondaguitan, Philippines
# ...

# %%
df.loc[df.title.str.contains('Arizona')]
# Out:
#        mag                              place  \
# 1062  1.23  7km SSW of Colorado City, Arizona
# 3965  0.94  7km WSW of Colorado City, Arizona
#
#                                           title  big_earthquake
# 1062  M 1.2 - 7km SSW of Colorado City, Arizona           False
# 3965  M 0.9 - 7km WSW of Colorado City, Arizona           False

# %%
df = pd.read_csv("earthquakes.csv")

# %%
df.loc[3:10, ['mag', 'magType', 'type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
df.mag
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327    0.62
# 9328    1.00
# 9329    2.40
# 9330    1.10
# 9331    0.66
# Name: mag, Length: 9332, dtype: float64

# %%
df.mag.sort_values(ascending=False)[0:10]
# Out:
# 5263    7.5
# 837     7.0
# 4363    6.7
# 118     6.7
# 799     6.5
# 816     6.2
# 838     6.1
# 5323    6.1
# 9211    6.0
# 862     6.0
# Name: mag, dtype: float64

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df.drop(columns = ['alert'])
# Out:
#       cdi        code                                             detail  \
# 0     NaN    37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1     NaN    37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2     4.4    37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3     NaN    37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4     NaN    73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...   ...         ...                                                ...
# 9327  NaN    73086771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9328  NaN    38063967  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9329  NaN  2018261000  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9330  NaN    38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331  NaN    38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#           dmin  felt    gap             ids   mag magType  mmi  ... sources  \
# ...

# %%
df = pd.read_csv("earthquakes.csv")

# %%
df.drop(columns='alert')
# Out:
#       cdi        code                                             detail  \
# 0     NaN    37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1     NaN    37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2     4.4    37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3     NaN    37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4     NaN    73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...   ...         ...                                                ...
# 9327  NaN    73086771  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9328  NaN    38063967  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9329  NaN  2018261000  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9330  NaN    38063959  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9331  NaN    38063935  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#           dmin  felt    gap             ids   mag magType  mmi  ... sources  \
# ...

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df = df.drop(columns='alert')

# %%
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag', 'magType',
#        'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
for col in df.columns: 
  if (col == 'mag' or col == 'magType'):
    print(col)
    df.pop(col)
# Out:
# mag
# magType

# %%
df = pd.read_csv("earthquakes.csv")

# %%
mag_df = pd.Series(df.mag)

# %%
magType_df = pd.Series(df.magType)

# %%
concat_df = pd.concat(mag_df, magType_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-3849bc1df567> in <module>
# ----> 1 concat_df = pd.concat(mag_df, magType_df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
# ...

# %%
for col in df.columns: 
  if (col == 'mag'):
    mag = df.pop(col)

# %%
df = pd.read_csv("earthquakes.csv")

# %% [markdown]
# SECOND TASK

# %%
for col in df.columns: 
  if (col == 'mag'):
    mag = df.pop(col)
  if (col == 'magType'):
    magType = df.pop(col)

pd.concat([mag, magType], axis=1)
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mmi',
#        'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mmi',
#        'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
for i in range(len(df.columns)):
  if df.columns[i] in ['tsunami', 'url']:
    print(i)
# Out:
# 18
# 23
